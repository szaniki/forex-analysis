# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

import os
from datetime import datetime
import pandas_datareader.data as web

# Visualisation
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use("seaborn-colorblind")

from pandas_datareader import data as web
from pandas import Series, DataFrame
import datetime
from operator import itemgetter # constructs a callable that assumes an iterable object (e.g. list, tuple, set) as input, and fetches the n-th element out of it.
from datetime import datetime
from datetime import datetime, timedelta

import statsmodels.api as sm

# %%
gbpusd = web.DataReader("GBPUSD=X", "yahoo", start=datetime(2000, 1, 1), # using Yahoo Finance API
                   end=datetime(2022, 10, 31),
                   )

gbpusd['Currency'] = 'GBP'
gbpusd
# Out:
#                 High       Low      Open     Close  Volume  Adj Close Currency
# Date
# 2003-12-01  1.727205  1.718390  1.723811  1.718597     0.0   1.718597      GBP
# 2003-12-02  1.732112  1.717298  1.719010  1.730313     0.0   1.730313      GBP
# 2003-12-03  1.731812  1.725209  1.730493  1.728101     0.0   1.728101      GBP
# 2003-12-04  1.728997  1.718302  1.727414  1.720697     0.0   1.720697      GBP
# 2003-12-05  1.733102  1.719809  1.720608  1.733102     0.0   1.733102      GBP
# ...              ...       ...       ...       ...     ...        ...      ...
# 2022-10-25  1.162358  1.143419  1.146066  1.146224     0.0   1.146224      GBP
# 2022-10-26  1.164415  1.155095  1.163345  1.163819     0.0   1.163819      GBP
# 2022-10-27  1.160012  1.150616  1.156738  1.156604     0.0   1.156604      GBP
# 2022-10-31  1.161332  1.147987  1.160079  1.159595     0.0   1.159595      GBP
# 2022-11-01  1.156524  1.144675  1.147184  1.146815     0.0   1.146815      GBP
#
# ...

# %%
gbpusd.to_csv('gbpusd_2000_2022.csv')

# %%
gbpusd.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# Currency     0
# dtype: int64

# %%
eurgbp = web.DataReader("EURGBP=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

eurgbp['Currency'] = 'EUR'
eurgbp
# Out:
#                High      Low     Open    Close  Volume  Adj Close Currency
# Date
# 2000-01-03  0.62900  0.62030  0.62390  0.62540     0.0    0.62540      EUR
# 2000-01-04  0.63140  0.62360  0.62530  0.62830     0.0    0.62830      EUR
# 2000-01-05  0.63300  0.62680  0.62810  0.62840     0.0    0.62840      EUR
# 2000-01-06  0.63160  0.62420  0.62960  0.62590     0.0    0.62590      EUR
# 2000-01-07  0.62940  0.62350  0.62650  0.62840     0.0    0.62840      EUR
# ...             ...      ...      ...      ...     ...        ...      ...
# 2022-10-25  0.86993  0.86460  0.86920  0.86920     0.0    0.86920      EUR
# 2022-10-26  0.86875  0.86186  0.86708  0.86708     0.0    0.86708      EUR
# 2022-10-27  0.86494  0.85750  0.86177  0.86177     0.0    0.86177      EUR
# 2022-10-31  0.86182  0.85719  0.85843  0.85843     0.0    0.85843      EUR
# 2022-11-01  0.86232  0.85975  0.86210  0.86210     0.0    0.86210      EUR
#
# [5948 rows x 7 columns]

# %%
eurgbp.to_csv('eurgbp_2000_2022.csv')

# %%
eurgbp.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# Currency     0
# dtype: int64

# %%
gbpjpy = web.DataReader("GBPJPY=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpjpy['Currency'] = 'JPY'
gbpjpy
# Out:
#                   High         Low        Open       Close  Volume  \
# Date
# 2003-12-01  189.660004  187.740005  189.330002  187.630005     0.0
# 2003-12-02  188.809998  187.559998  187.669998  188.009995     0.0
# 2003-12-03  188.240005  186.490005  188.020004  187.089996     0.0
# 2003-12-04  187.029999  185.899994  187.029999  186.220001     0.0
# 2003-12-05  186.740005  185.830002  186.190002  185.880005     0.0
# ...                ...         ...         ...         ...     ...
# 2022-10-25  170.582993  169.356995  169.598999  169.598999     0.0
# 2022-10-26  170.031006  168.759995  170.052002  170.052002     0.0
# 2022-10-27  171.044998  168.899994  169.132004  169.132004     0.0
# 2022-10-31  172.100998  170.740005  171.376007  171.376007     0.0
# 2022-11-01  170.919006  169.576996  170.550995  170.550995     0.0
#
#              Adj Close Currency
# Date
# 2003-12-01  187.630005      JPY
# 2003-12-02  188.009995      JPY
# 2003-12-03  187.089996      JPY
# ...

# %%
gbpjpy.to_csv('gbpjpy_2000_2022.csv')

# %%
gbpjpy.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# Currency     0
# dtype: int64

# %% [markdown]
# # Brexit data

# %%
gbpusd_brexit = web.DataReader("GBPUSD=X", "yahoo", start=datetime(2015, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpusd_brexit
# Out:
#                 High       Low      Open     Close  Volume  Adj Close
# Date
# 2015-01-01  1.558094  1.558094  1.558094  1.558094     0.0   1.558094
# 2015-01-02  1.558458  1.538746  1.558021  1.557972     0.0   1.557972
# 2015-01-05  1.532004  1.520612  1.528608  1.528491     0.0   1.528491
# 2015-01-06  1.527370  1.515795  1.525832  1.525832     0.0   1.525832
# 2015-01-07  1.515611  1.506796  1.513638  1.513798     0.0   1.513798
# ...              ...       ...       ...       ...     ...        ...
# 2022-10-25  1.162358  1.143419  1.146066  1.146224     0.0   1.146224
# 2022-10-26  1.164415  1.155095  1.163345  1.163819     0.0   1.163819
# 2022-10-27  1.160012  1.150616  1.156738  1.156604     0.0   1.156604
# 2022-10-31  1.161332  1.147987  1.160079  1.159595     0.0   1.159595
# 2022-11-01  1.156524  1.144675  1.147184  1.146815     0.0   1.146815
#
# [2041 rows x 6 columns]

# %%
gbpjpy_brexit = web.DataReader("GBPJPY=X", "yahoo", start=datetime(2015, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpjpy_brexit['Currency'] = 'JPY'
gbpjpy_brexit
# Out:
#                   High         Low        Open       Close  Volume  \
# Date
# 2015-01-01  186.429993  186.429993  186.429993  186.429993     0.0
# 2015-01-02  187.294998  184.822006  186.740005  186.764999     0.0
# 2015-01-05  184.376999  181.729004  184.080002  184.078003     0.0
# 2015-01-06  182.330994  180.100006  182.160995  182.205002     0.0
# 2015-01-07  180.589005  179.600006  179.615997  179.625000     0.0
# ...                ...         ...         ...         ...     ...
# 2022-10-25  170.582993  169.356995  169.598999  169.598999     0.0
# 2022-10-26  170.031006  168.759995  170.052002  170.052002     0.0
# 2022-10-27  171.044998  168.899994  169.132004  169.132004     0.0
# 2022-10-31  172.100998  170.740005  171.376007  171.376007     0.0
# 2022-11-01  170.919006  169.576996  170.550995  170.550995     0.0
#
#              Adj Close Currency
# Date
# 2015-01-01  186.429993      JPY
# 2015-01-02  186.764999      JPY
# 2015-01-05  184.078003      JPY
# ...

# %%
eurgpb_brexit = web.DataReader("EURGBP=X", "yahoo", start=datetime(2015, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

eurgpb_brexit['Currency'] = 'EUR'
eurgpb_brexit
# Out:
#                High      Low     Open    Close  Volume  Adj Close Currency
# Date
# 2015-01-01  0.77616  0.77616  0.77616  0.77616     0.0    0.77616      EUR
# 2015-01-02  0.78166  0.77450  0.77584  0.77590     0.0    0.77590      EUR
# 2015-01-05  0.78436  0.78010  0.78154  0.78148     0.0    0.78148      EUR
# 2015-01-06  0.78554  0.78190  0.78230  0.78240     0.0    0.78240      EUR
# 2015-01-07  0.78527  0.78150  0.78430  0.78444     0.0    0.78444      EUR
# ...             ...      ...      ...      ...     ...        ...      ...
# 2022-10-25  0.86993  0.86460  0.86920  0.86920     0.0    0.86920      EUR
# 2022-10-26  0.86875  0.86186  0.86708  0.86708     0.0    0.86708      EUR
# 2022-10-27  0.86494  0.85750  0.86177  0.86177     0.0    0.86177      EUR
# 2022-10-31  0.86182  0.85719  0.85843  0.85843     0.0    0.85843      EUR
# 2022-11-01  0.86232  0.85975  0.86210  0.86210     0.0    0.86210      EUR
#
# [2042 rows x 7 columns]

# %%
gbpeur_brexit = web.DataReader("GBPEUR=X", "yahoo", start=datetime(2015, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpeur_brexit['Currency'] = 'GBP'
gbpeur_brexit
# Out:
#                High      Low     Open    Close  Volume  Adj Close Currency
# Date
# 2015-01-01  1.28720  1.28720  1.28720  1.28720     0.0    1.28720      GBP
# 2015-01-02  1.29090  1.27920  1.28870  1.28850     0.0    1.28850      GBP
# 2015-01-05  1.28170  1.27450  1.27930  1.27940     0.0    1.27940      GBP
# 2015-01-06  1.27860  1.27260  1.27784  1.27800     0.0    1.27800      GBP
# 2015-01-07  1.27930  1.27310  1.27470  1.27446     0.0    1.27446      GBP
# ...             ...      ...      ...      ...     ...        ...      ...
# 2022-10-25  1.15646  1.14937  1.15028  1.15028     0.0    1.15028      GBP
# 2022-10-26  1.16011  1.15091  1.15308  1.15308     0.0    1.15308      GBP
# 2022-10-27  1.16600  1.15601  1.16018  1.16018     0.0    1.16018      GBP
# 2022-10-31  1.16638  1.16010  1.16464  1.16464     0.0    1.16464      GBP
# 2022-11-01  1.16301  1.15948  1.15991  1.15991     0.0    1.15991      GBP
#
# [2042 rows x 7 columns]

# %% [markdown]
# # Plotting Brexit

# %%
#data = pd.read_csv('gbp_brexit_from2015.csv')
#data.set_index('Date')

plt.figure(figsize=(15, 8))
plt.title('GBP/USD exchange high vs low price')
plt.plot(gbpusd_brexit['High'], label='High')
plt.plot(gbpusd_brexit['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/USD exchange rate')
plt.legend()

# %%
plt.savefig('gbpusd_brexit.png', transparent=True)

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/JPY exchange high vs low')
plt.plot(gbpjpy_brexit['High'], label='High')
plt.plot(gbpjpy_brexit['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/JPY exchange rate')
plt.legend()

# %%
plt.savefig('gbpjpy_brexit.jpg', transparent=True)

# %%
plt.figure(figsize=(15, 8))
plt.title('EUR/GBP exchange high vs low price')
plt.plot(eurgpb_brexit['High'], label='High')
plt.plot(eurgpb_brexit['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('EUR/GBP exchange rate')
plt.legend()

# %%
plt.savefig('eurgpb_brexit.jpg', transparent=True)

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/EUR exchange high vs low')
plt.plot(gbpeur_brexit['High'], label='High')
plt.plot(gbpeur_brexit['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/EUr exchange rate')
plt.legend()

# %% [markdown]
# # Plotting Covid

# %%
gbpusd_covid = web.DataReader("GBPUSD=X", "yahoo", start=datetime(2019, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpusd_covid['Currency'] = 'GBP'

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/USD exchange high vs low price')
plt.plot(gbpusd_covid['High'], label='High')
plt.plot(gbpusd_covid['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/USD exchange rate')
plt.legend()

# %%
gbpjpy_covid = web.DataReader("GBPJPY=X", "yahoo", start=datetime(2019, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpjpy_covid['Currency'] = 'JPY'

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/JPY exchange high vs low price')
plt.plot(gbpusd_covid['High'], label='High')
plt.plot(gbpusd_covid['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/JPY exchange rate')
plt.legend()

# %%
gbpeur_covid = web.DataReader("GBPEUR=X", "yahoo", start=datetime(2019, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpeur_covid['Currency'] = 'GBP'

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/EUR exchange high vs low price')
plt.plot(gbpeur_covid['High'], label='High')
plt.plot(gbpeur_covid['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/EUR exchange rate')
plt.legend()

# %% [markdown]
# # Graphs based on historical data

# %%
gbpusd_historical = web.DataReader("GBPUSD=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpusd_historical['Currency'] = 'GBP'

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/USD exchange high vs low price')
plt.plot(gbpusd_historical['High'], label='High')
plt.plot(gbpusd_historical['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/USD exchange rate')
plt.legend()

# %%
gbpjpy_historical = web.DataReader("GBPJPY=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpjpy_historical['Currency'] = 'GBP'

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/JPY exchange high vs low price')
plt.plot(gbpjpy_historical['High'], label='High')
plt.plot(gbpjpy_historical['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/JPY exchange rate')
plt.legend()

# %%
gbpeur_historical = web.DataReader("GBPEUR=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpeur_historical['Currency'] = 'GBP'

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/EUR exchange high vs low price')
plt.plot(gbpeur_historical['High'], label='High')
plt.plot(gbpeur_historical['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/EUR exchange rate')
plt.legend()

# %%
gbpchf_historical = web.DataReader("GBPCHF=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbpchf_historical['Currency'] = 'GBP'

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/CHF exchange high vs low price')
plt.plot(gbpchf_historical['High'], label='High')
plt.plot(gbpchf_historical['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/CHF exchange rate')
plt.legend()

# %%
gbphuf_historical = web.DataReader("GBPHUF=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

gbphuf_historical['Currency'] = 'GBP'

# %%
usdhuf_historical = web.DataReader("USDHUF=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

usdhuf_historical['Currency'] = 'USD'

# %%
plt.figure(figsize=(15, 8))
plt.title('GBP/JPY exchange high vs low')
plt.plot(gbpjpy['High'], label='High')
plt.plot(gbpjpy['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('GBP/JPY rate')
plt.legend()

# %%
eurhuf = web.DataReader("EURHUF=X", "yahoo", start=datetime(2000, 1, 1),
                   end=datetime(2022, 10, 31),
                   )

# %%
plt.figure(figsize=(15, 8))
plt.title('EUR/HUF exchange high vs low')
plt.plot(gbpjpy['High'], label='High')
plt.plot(gbpjpy['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('EUR/HUF rate')
plt.legend()
